# %% [markdown]
# ![car_logo.png](attachment:car_logo.png)

# %% [markdown]
# # 1 - Problem Statement

# %% [markdown]
# 1 - Analysis of most economic company car for City and highway in the context of price and mileage.
#
# 2 - Car Body specification ( length,width,height) ,  wheel-base and engine specification ( engine-type ,num-of-cylinders,engine-size ) affect the car price.

# %% [markdown]
# # 2 - About Meta-Data

# %% [markdown]
# Source:- https://archive.ics.uci.edu/ml/datasets/automobile
#
# Data Volume:- 205 Records , 26 Columns

# %% [markdown]
# ### 2.1- Column Information and Range:

# %%
1- symboling            : mark of the automobile [ -3, -2, -1, 0, 1, 2, 3.]
2- normalized-losses    : relative average loss payment per insured vehicle year.[ ontinuous from 65 to 256.]
3- make                 : manufacturer name
4- fuel-type            : Type of Fule used [ diesel, gas.]
5- aspiration           : Type of Induction ( Supercharging and Turbocharging)
6- num-of-doors         : Total Door in vehicle [ four, two ]
7- body-style           : Body style of car [hardtop, wagon, sedan, hatchback, convertible.]
8- drive-wheels         : 4wd, fwd, rwd
9- engine-location      : engine location fron or back
10- wheel-base          : wheelbase is the distance between the centers of the front and rear wheels.
11- length              : length of car [continuous from 141.1 to 208.1]
12- width                : width of car [ continuous from 60.3 to 72.3 ]
13- Height               : Height of the car [continuous from 47.8 to 59.8]
14- curb-weight          : total mass of a vehicle with standard equipment and all necessary operating 
15- engine-type          : engine type [dohc, dohcv, l, ohc, ohcf, ohcv, rotor.]
16- num-of-cylinders     : Total cyclinders in engine [eight, five, four, six, three, twelve, two.]
17- engine-size          : engine Size [continuous from 61 to 326]
18- fuel-system          : fuel system is to store and supply fuel to the engine [1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi]
19- bore                 : inside diameter of engine's cylinder [continuous from 2.54 to 3.94]
20- stroke               : continuous from 2.07 to 4.17
21- compression-ratio    : continuous from 7 to 23
22- horsepower           : continuous from 48 to 288
23- peak-rpm             : continuous from 4150 to 6600
24- city-mpg             : average of fule in city ( Miles Per Gallon) [continuous from 13 to 49]
25- highway-mpg          : average of fule in highway [continuous from 16 to 54]
26- price                : Price of car [continuous from 5118 to 45400]

# %% [markdown]
# # 3- Data Loading

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pandas_profiling

df = pd.read_csv("C:\Automobile_data.csv")
print( " Successfully loaded")
# Out:
#  Successfully loaded

# %% [markdown]
# # 4- Data Profiling

# %% [markdown]
# ### Statistics Discription of Dataset

# %%
info = df.shape
print( " number of rows = ",info[0])
print( " Number of column = ",info[1])
df.isnull().sum()
# Out:
#  number of rows =  205
#  Number of column =  26
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# # 5- Pre Profiling

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file(output_file= "pre_automobile.html",silent=False)

# %% [markdown]
# # 6- Data Clean-Up ( Pre Processing)

# %% [markdown]
# some of columns having "?" values ,It consider as missing values and it is replaced by appropriate value

# %% [markdown]
# #### 6.1- "normalized-losses"

# %% [markdown]
# "?" is consider as  missing vlaues. it can be replace ? with the mean values of all  "normalized-losses"

# %%
print( "Number of record in column = normalized-losses having ?--> {0}".format(df[ df["normalized-losses"] == "?"]["normalized-losses"].count()))
#convert string to float
df["normalized-losses"]  = pd.to_numeric(arg=df["normalized-losses"] ,errors = "coerce" )
df["normalized-losses"].fillna(value= df["normalized-losses"].mean(),inplace =True)
print( "Number of record in column = normalized-losses having ?--> {0}".format(df[ df["normalized-losses"] == "?"]["normalized-losses"].count()))
# Out:
# Number of record in column = normalized-losses having ?--> 41
# Number of record in column = normalized-losses having ?--> 0
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# #### 6.2- "num-of-doors"

# %% [markdown]
# Column "num-of-doors" is having categorical data. There are only 2 records having "?". Replace the ? to the mode of "num-of-doors" on the basis of column "make" and "body-style".

# %%
print(" Total number of ? in columns = num-of-doors ---> ",df[ df["num-of-doors" ] == "?" ]["num-of-doors" ].count())
df["num-of-doors" ].replace(to_replace="?",value= df[ (df["body-style"] == "sedan") &  (df["make"] == "dodge")]["num-of-doors" ].mode()[0],inplace =True)
df["num-of-doors" ].replace(to_replace="?",value= df[ (df["body-style"] == "sedan") &  (df["make"] == "mazda")]["num-of-doors" ].mode()[0],inplace =True)
print(" Total number of ? in columns = num-of-doors ---> ",df[ df["num-of-doors" ] == "?" ]["num-of-doors" ].count())
# Out:
#  Total number of ? in columns = num-of-doors --->  2
#  Total number of ? in columns = num-of-doors --->  0

# %% [markdown]
# #### 6.3- "bore"

# %% [markdown]
# Column "bore" is having numerical data,data "?" is replaced by NAN

# %%
print(" Total number of ? in column = bore ---> ",df[ df["bore" ] == "?" ]["bore" ].count())
df["bore"]  = pd.to_numeric(arg=df["bore"] ,errors = "coerce" )
print(" Total number of ? in column = bore ---> ",df[ df["bore" ] == "?" ]["bore" ].count())
# Out:
#  Total number of ? in column = bore --->  4
#  Total number of ? in column = bore --->  0

# %% [markdown]
# #### 6.4- "stroke"

# %% [markdown]
# Column "stroke" is having numerical data,data "?" is replaced by NAN

# %%
print(" Total number of ? in column = stroke ---> ",df[ df["stroke" ] == "?" ]["stroke" ].count())
df["stroke"]=pd.to_numeric(arg=df["stroke"] ,errors = "coerce")
print(" Total number of ? in column = stroke ---> ",df[ df["stroke" ] == "?" ]["stroke" ].count())
# Out:
#  Total number of ? in column = stroke --->  4
#  Total number of ? in column = stroke --->  0

# %% [markdown]
# #### 6.5- "peak-rpm"

# %% [markdown]
# Column "peak-rpm" is having numerical data,data "?" is replaced by NAN

# %%
#clean the column "peak-rpm" and set NAN
print(" Total number of ? in column = peak-rpm ---> ",df[ df["peak-rpm" ] == "?" ]["peak-rpm" ].count())
df["peak-rpm"]=pd.to_numeric(arg=df["peak-rpm"] ,errors = "coerce")
print(" Total number of ? in column = peak-rpm ---> ",df[ df["peak-rpm" ] == "?" ]["peak-rpm" ].count())
# Out:
#  Total number of ? in column = peak-rpm --->  2
#  Total number of ? in column = peak-rpm --->  0

# %% [markdown]
# #### 6.6- "price"

# %% [markdown]
# "?" in "price" column is  replaced by mean value

# %%
# get the numeric and non numeric values
df["price"].str.isnumeric().value_counts()
#get the mean of numeric values
nPrice = df["price"].loc[df["price"].str.isnumeric()== True]
mPrice = nPrice.astype(int).mean()
#replce by mean
df['price'] = df['price'].replace('?',mPrice).astype(int)

# %% [markdown]
# #### 6.7- "horsepower"

# %% [markdown]
# "?" in "horsepower" column is replaced by mean value

# %%
# get the numeric and non numeric values
df['horsepower'].str.isnumeric().value_counts()
nhorsepower = df['horsepower'].loc[ df['horsepower'].str.isnumeric() == True]
mhorsepower = nhorsepower.astype(int).mean()
mhorsepower
#replce by mean
df['horsepower'] = df['horsepower'].replace('?',mhorsepower).astype(int)

# %%
#save data set in csv file
df.to_csv("C:\Automobile_cleaned_data.csv")

# %% [markdown]
# # 7- Post Pandas Profiling

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file(output_file= "post_automobile.html",silent=False)

# %%
df.head(df.shape[0]) # display complete data set
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %% [markdown]
# # 8- Problem Statement 1- Most economic company car for City and highway

# %% [markdown]
# #### 8.1- Frequency diagram for make

# %%
df.make.value_counts().plot.bar()

# %%
print(  "Bigest manufacturer of car is Toyota : %f" %((df[ df["make"] == "toyota"].shape[0]) * 100/ df["make"].shape[0]),"%" )
print(  "Least manufacturer of car is Mercury : %f" %((df[ df["make"] == "mercury"].shape[0]) * 100/ df["make"].shape[0]),"%" )
# Out:
# Bigest manufacturer of car is Toyota : 15.609756 %
# Least manufacturer of car is Mercury : 0.487805 %

# %% [markdown]
# #### 8.2- Risk rating (symboling) Histogram

# %%
df.symboling.plot(kind="hist")
# risk rating is from -3 to 3 , but it start from -2. most of car having risk rating between 0 to 1

# %% [markdown]
# #### 8.3- Frequency diagram for fule type

# %%
df["fuel-type"].value_counts().plot(kind="bar")

# %%
df["fuel-type"].value_counts().plot(kind="pie",autopct='%.2f')

# %% [markdown]
# Answer:-
#         percentage manufactured car according fuel Type
#
#             gas  = 90.24%
#
#             desel = 9.76%
#
#      gas fuel car are in most demand

# %% [markdown]
# #### 8.4- Distribution of sales price

# %%
sns.distplot(df['price'],color ='g')

print("Skewness: %f" % df['price'].skew())
print("Kurtosis: %f" % df['price'].kurt())

#plot is skewed towards the left it means very less car having high price
# Out:
# Skewness: 1.827325
# Kurtosis: 3.354218

# %% [markdown]
# #### 8.5- Number of doors - pie chart

# %%
df["num-of-doors"].value_counts().plot(kind="pie",figsize = (6,9),autopct='%.2f')

# 56.59 % cars are four door
# 43.41 % cars are two  door

# %% [markdown]
# #### 8.6- Box Plot between make and Price

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(15,8))
ax = sns.boxplot( x="make",y="price",hue= "num-of-doors",data = df)

# 1 - Most expensive car is mercedes two door and least expensive is Chevrolet two door. 
# 2- Premium car above 20000 are bmw,Jaquar, Mercedes benz and Porsche.
# 3- car less then 10000 are Chevrolet, Dodge, Honda, Mitsubishi, Plymoth and Subaru.
# 4- Rest car are in middle range.

# %% [markdown]
# #### 8.7- Box Plot between city-mpg , make and hue is Fule type

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="make",y="city-mpg",hue="fuel-type", data = df)
# least expensive car "Chevrolet" fule type = "gas" is very good in city mileage

# %% [markdown]
# #### 8.8- Box Plot between highway-mpg  , make and hue is Fule type

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="make",y="highway-mpg",hue="fuel-type", data = df)
# least expensive car "Chevrolet" fule type = "gas" is very good in High mileage

# %% [markdown]
# ### 8.9- Summary

# %% [markdown]
# 1- "Toyota" manufactored most number of vehicles which is 15.60% than the 2nd "Nissan" that is 8.78 % and least is "Mercury".
#
# 2- Most manufactored fuel type car is "gass" which is 90.24%
#
# 3- Risk rating is from -3 to 3, in given data set it it starts from -2 and most of car having risk rating between 0 to 1.
#
# 4- Most expensive car is "mercedes" and least expensive is "Chevrolet". Both are two door car.
#
# 5- Premium car above 20000 are bmw,Jaquar, Mercedes benz and Porsche.
#
# 6- car less then 10000 are Chevrolet, Dodge, Honda, Mitsubishi, Plymoth and Subaru and rest are in middle range.
#
# 7- Least expensive car "Chevrolet" fule type = "gas" is very good in City/High mileage

# %% [markdown]
# # 9- Problem Statement 2:- Body specification , wheels base and engine specification affect the car price.

# %% [markdown]
# #### 9.1- Scatter plot between engine size and price

# %%
sns.lmplot(x="engine-size",y="price",data=df)
# there is a linear releation between price  and engine size.

# %% [markdown]
# #### 9.2- Scatter plot between engine size and horsepower

# %%
sns.lmplot(y="horsepower",x="engine-size", data=df, hue="make",fit_reg=False)
# as engine size increase power of engine increase

# %% [markdown]
# #### 9.3- Scatter plot between horsepower and price

# %%
sns.lmplot(x="horsepower",y="price",data=df)
# there is a linear releation between price  and horsepower.

# %% [markdown]
# #### 9.4- Scatter plot between wheel-base and price

# %%
sns.lmplot(x="wheel-base",y="price",data=df)
# there is a linear releation between price  and wheel-base.

# %% [markdown]
# #### 9.5- Scatter plot between City mileage and price

# %%
sns.lmplot(x="city-mpg",y="price",data=df)
# there is a negetive correlation bewteen city mileage and price. if any car is having  high- city mileage , its price is low

# %% [markdown]
# #### 9.6- Scatter plot between High mileage and price

# %%
sns.lmplot(x="highway-mpg",y="price",data=df)
# there is a negetive correlation bewteen highway mileage and price.

# %% [markdown]
# #### 9.7- Summary
#
# ###### 1- There is a positive linear releation between engine size and price, engine size and horsepower, horsepower and price and wheel-base and price.
# ###### 2- As engine and physical specificatin increases,price increases.
# ###### 3- City and High mileage are having negative linear relation with price.

# %% [markdown]
# # 10-  Correlation Analysis

# %%
plt.figure(figsize=(15,8))
sns.heatmap(  df.loc[:,  ["symboling","normalized-losses","wheel-base","length","width","height","curb-weight","engine-size","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"] ].corr()  , annot=True)

# %% [markdown]
# #### 10.1- Summary

# %% [markdown]
# 1-  Engine size and crub weigth of car are highly correlated with price
#
# 2-  Wheel base is highly correlated with length and width
#
# 3-  Engine size is higly correlated with hoursepower

# %% [markdown]
# # Conclusion

# %% [markdown]
# #####  1- Engine specifications and body characters of car affect price. As specification and characters increase , prices increases.
# ##### 2- Least expensive car manufacture  is "Chevrolet" fule type = "gas" for city/Highway but Toyota 's car sale is high.
